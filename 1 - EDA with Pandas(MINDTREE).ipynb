# %% [markdown]
# # Preliminary Setup

# %%
# %matplotlib inline
import os
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
os.chdir(r'D:/DS')
cwd = os.getcwd()
print(cwd)
warnings.filterwarnings('ignore')
# Out:
# D:\DS

# %% [markdown]
# # Problem Statement 1.1
# Import the csv file of the stock of your choosing using 'pd.read_csv()' function into a dataframe. Shares of a company can be offered in more than one category. The category of a stock is indicated in the ‘Series’ column. If the csv file has data on more than one category, the ‘Date’ column will have repeating values. To avoid repetitions in the date, remove all the rows where 'Series' column is NOT 'EQ'. Analyze and understand each column properly. You'd find the head(), tail() and describe() functions to be immensely useful for exploration. You're free to carry out any other exploration of your own.

# %%
data = pd.read_csv(r'MINDTREE.csv')

# %%
data.shape
# Out:
# (494, 15)

# %%
data.head()
# Out:
#      Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0  MINDTREE     EQ  15-May-2017      510.60      507.35      515.00
# 1  MINDTREE     EQ  16-May-2017      509.45      507.00      515.85
# 2  MINDTREE     EQ  17-May-2017      511.30      507.05      519.70
# 3  MINDTREE     EQ  18-May-2017      506.35      502.00      516.75
# 4  MINDTREE     EQ  19-May-2017      492.90      491.95      502.95
#
#    Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0     505.90      510.50       509.45         510.39                 271952
# 1     506.00      511.00       511.30         512.69                 207011
# 2     502.75      504.00       506.35         512.10                 391401
# 3     486.00      487.50       492.90         505.60                 852336
# 4     489.50      495.15       497.50         496.43                 352273
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
data.tail()
# Out:
#        Symbol Series         Date  Prev Close  Open Price  High Price  \
# 489  MINDTREE     EQ  07-May-2019      981.75       982.8      985.00
# 490  MINDTREE     EQ  08-May-2019      979.95       981.0      985.00
# 491  MINDTREE     EQ  09-May-2019      980.50       979.6      983.15
# 492  MINDTREE     EQ  10-May-2019      980.45       980.4      982.90
# 493  MINDTREE     EQ  13-May-2019      975.35       973.4      983.00
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 489     975.00       981.0       979.95         979.77                1242934
# 490     971.05       982.0       980.50         979.84                4301316
# 491     976.10       980.9       980.45         980.02                3787159
# 492     973.00       974.0       975.35         977.55                 215170
# 493     970.30       981.0       979.10         980.16                 485941
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
data.describe()
# Out:
#         Prev Close   Open Price   High Price    Low Price   Last Price  \
# count   494.000000   494.000000   494.000000   494.000000   494.000000
# mean    778.486032   779.720547   792.118421   767.127328   779.634919
# std     214.140514   214.851383   218.056333   210.381329   214.484986
# min     442.500000   443.000000   448.750000   439.050000   441.400000
# 25%     537.025000   537.975000   545.862500   528.012500   535.862500
# 50%     835.075000   838.000000   851.525000   820.625000   835.025000
# 75%     968.137500   968.500000   980.500000   949.450000   969.950000
# max    1161.950000  1165.000000  1183.800000  1147.800000  1166.000000
#
#        Close Price  Average Price  Total Traded Quantity      Turnover  \
# count   494.000000     494.000000           4.940000e+02  4.940000e+02
# mean    779.434413     780.076619           1.388615e+06  1.191635e+09
# std     213.989087     214.038370           1.450169e+06  1.373025e+09
# ...

# %%
#Remove null values to avoid future errors
data.dropna(inplace = True)

# %%
#Checking type of Turnover Column since the values are displayed in exponential form with an 'e'
data.dtypes
# Out:
# Symbol                     object
# Series                     object
# Date                       object
# Prev Close                float64
# Open Price                float64
# High Price                float64
# Low Price                 float64
# Last Price                float64
# Close Price               float64
# Average Price             float64
# Total Traded Quantity       int64
# Turnover                  float64
# No. of Trades               int64
# Deliverable Qty             int64
# % Dly Qt to Traded Qty    float64
# dtype: object

# %%
# Check for NOT 'EQ' values in Series column
data[data.Series != 'EQ']
# Out:
# Empty DataFrame
# Columns: [Symbol, Series, Date, Prev Close, Open Price, High Price, Low Price, Last Price, Close Price, Average Price, Total Traded Quantity, Turnover, No. of Trades, Deliverable Qty, % Dly Qt to Traded Qty]
# Index: []

# %% [markdown]
# #### Therefore, there are no rows where Series is not 'EQ'

# %%
data.apply(np.max)
# Out:
# Symbol                       MINDTREE
# Series                             EQ
# Date                      31-Oct-2018
# Prev Close                    1161.95
# Open Price                       1165
# High Price                     1183.8
# Low Price                      1147.8
# Last Price                       1166
# Close Price                   1161.95
# Average Price                 1167.48
# Total Traded Quantity        13385207
# Turnover                  1.29887e+10
# No. of Trades                  311806
# Deliverable Qty               3851210
# % Dly Qt to Traded Qty          91.89
# dtype: object

# %%
data.apply(np.min)
# Out:
# Symbol                       MINDTREE
# Series                             EQ
# Date                      01-Apr-2019
# Prev Close                      442.5
# Open Price                        443
# High Price                     448.75
# Low Price                      439.05
# Last Price                      441.4
# Close Price                     442.5
# Average Price                  442.24
# Total Traded Quantity           46300
# Turnover                  2.30558e+07
# No. of Trades                    1502
# Deliverable Qty                 15053
# % Dly Qt to Traded Qty           5.87
# dtype: object

# %% [markdown]
# # Problem Statement 1.2
# Calculate the maximum, minimum and mean price for the last 90 days. (price=Closing Price unless stated otherwise)

# %%
data.head()
# Out:
#      Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0  MINDTREE     EQ  15-May-2017      510.60      507.35      515.00
# 1  MINDTREE     EQ  16-May-2017      509.45      507.00      515.85
# 2  MINDTREE     EQ  17-May-2017      511.30      507.05      519.70
# 3  MINDTREE     EQ  18-May-2017      506.35      502.00      516.75
# 4  MINDTREE     EQ  19-May-2017      492.90      491.95      502.95
#
#    Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0     505.90      510.50       509.45         510.39                 271952
# 1     506.00      511.00       511.30         512.69                 207011
# 2     502.75      504.00       506.35         512.10                 391401
# 3     486.00      487.50       492.90         505.60                 852336
# 4     489.50      495.15       497.50         496.43                 352273
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
data.tail()
# Out:
#        Symbol Series         Date  Prev Close  Open Price  High Price  \
# 489  MINDTREE     EQ  07-May-2019      981.75       982.8      985.00
# 490  MINDTREE     EQ  08-May-2019      979.95       981.0      985.00
# 491  MINDTREE     EQ  09-May-2019      980.50       979.6      983.15
# 492  MINDTREE     EQ  10-May-2019      980.45       980.4      982.90
# 493  MINDTREE     EQ  13-May-2019      975.35       973.4      983.00
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 489     975.00       981.0       979.95         979.77                1242934
# 490     971.05       982.0       980.50         979.84                4301316
# 491     976.10       980.9       980.45         980.02                3787159
# 492     973.00       974.0       975.35         977.55                 215170
# 493     970.30       981.0       979.10         980.16                 485941
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
data['Close Price'].max()
# Out:
# 1161.95

# %%
data['Close Price'].min()
# Out:
# 442.5

# %%
data['Close Price'].mean()
# Out:
# 779.4344129554655

# %% [markdown]
# #### The above (max, min, mean) was for all the dates under consideration.
# #### For only past 90 days we have modify the Date values

# %%
data['Date'].dtype
# Out:
# dtype('O')

# %%
data['Index'] = data.index
data.tail()
# Out:
#        Symbol Series         Date  Prev Close  Open Price  High Price  \
# 489  MINDTREE     EQ  07-May-2019      981.75       982.8      985.00
# 490  MINDTREE     EQ  08-May-2019      979.95       981.0      985.00
# 491  MINDTREE     EQ  09-May-2019      980.50       979.6      983.15
# 492  MINDTREE     EQ  10-May-2019      980.45       980.4      982.90
# 493  MINDTREE     EQ  13-May-2019      975.35       973.4      983.00
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 489     975.00       981.0       979.95         979.77                1242934
# 490     971.05       982.0       980.50         979.84                4301316
# 491     976.10       980.9       980.45         980.02                3787159
# 492     973.00       974.0       975.35         977.55                 215170
# 493     970.30       981.0       979.10         980.16                 485941
#
# ...

# %%
# create a separate dataframe only for past 90 days
data90 = data.loc[(data['Index'] >= 403) & (data['Index'] <= 493)]

# %%
data90.head()
# Out:
#        Symbol Series         Date  Prev Close  Open Price  High Price  \
# 403  MINDTREE     EQ  28-Dec-2018      861.85      863.00       869.0
# 404  MINDTREE     EQ  31-Dec-2018      864.10      870.00       871.7
# 405  MINDTREE     EQ  01-Jan-2019      864.50      864.00       867.1
# 406  MINDTREE     EQ  02-Jan-2019      863.40      858.00       878.0
# 407  MINDTREE     EQ  03-Jan-2019      860.50      861.15       865.0
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 403     858.05      865.20        864.1         863.70                 420544
# 404     861.55      864.00        864.5         866.31                 317152
# 405     853.40      863.15        863.4         861.25                 399996
# 406     857.20      859.00        860.5         870.52                 892157
# 407     824.35      834.30        834.8         848.07                 908897
#
# ...

# %%
data90.tail()
# Out:
#        Symbol Series         Date  Prev Close  Open Price  High Price  \
# 489  MINDTREE     EQ  07-May-2019      981.75       982.8      985.00
# 490  MINDTREE     EQ  08-May-2019      979.95       981.0      985.00
# 491  MINDTREE     EQ  09-May-2019      980.50       979.6      983.15
# 492  MINDTREE     EQ  10-May-2019      980.45       980.4      982.90
# 493  MINDTREE     EQ  13-May-2019      975.35       973.4      983.00
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 489     975.00       981.0       979.95         979.77                1242934
# 490     971.05       982.0       980.50         979.84                4301316
# 491     976.10       980.9       980.45         980.02                3787159
# 492     973.00       974.0       975.35         977.55                 215170
# 493     970.30       981.0       979.10         980.16                 485941
#
# ...

# %% [markdown]
# #### Now, we have a subset of the original data only for the past 90 days

# %%
data90['Close Price'].max()
# Out:
# 989.4

# %%
data90['Close Price'].min()
# Out:
# 812.25

# %%
data90['Close Price'].mean()
# Out:
# 918.0131868131863

# %% [markdown]
# # Problem Statement 1.3
# Analyse the data types for each column of the dataframe. Pandas knows how to deal with dates in an intelligent manner. But to make use of Pandas functionality for dates, you need to ensure that the column is of type 'datetime64(ns)'. Change the date column from 'object' type to 'datetime64(ns)' for future convenience. See what happens if you subtract the minimum value of the date column from the maximum value.

# %%
data['Date'].dtype
# Out:
# dtype('O')

# %%
from datetime import datetime
data['Date'] = data['Date'].astype(datetime)

# %%
data['Date'].dtype
# Out:
# dtype('O')

# %%
data['Date'] = pd.to_datetime(data['Date'], errors='coerce')

# %%
data['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
np.dtype('datetime64[ns]') == np.dtype('<M8[ns]')
# Out:
# True

# %%
data['Date'].max() - data['Date'].min()
# Out:
# Timedelta('728 days 00:00:00')

# %% [markdown]
# # Problem Statement 1.4
# In a separate array , calculate the monthwise VWAP (Volume Weighted Average Price ) of the stock.
# ( VWAP = sum(price*volume)/sum(volume) )
# To know more about VWAP , visit - VWAP definition
# {Hint : Create a new dataframe column ‘Month’. The values for this column can be derived from the ‘Date” column by using appropriate pandas functions. Similarly, create a column ‘Year’ and initialize it. Then use the 'groupby()' function by month and year. Finally, calculate the vwap value for each month (i.e. for each group created).

# %% [markdown]
# Key Takeaways regarding VWAPS:
#
# 1. The volume weighted average price (VWAP) appears as a single line on intraday charts (1 minute, 15 minute, and so on), similar to how a moving average looks.
#
# 2. A rising VWAP, and/or the price above the VWAP line, means the price is likely in an uptrend.
#
# 3. A declining VWAP, and/or the price below the VWAP line, means the price is likely in a downtrend.
#
# 4. Don't rely on VWAP exclusively to determine trend, since it is only showing a historical average, and not what is happening currently or in the future.
#
# 5. Investors may use VWAP to assess the price they paid for a security throughout the day. At the end of the day, if the price they bought at is higher than the VWAP, then they may have overpaid. If it is less than VWAP, then they purchased shares at a good price for that day.
#
# Formula to calculate VWAP:
#
# VWAP is calculated by adding up the dollars traded for every transaction (price multiplied by the number of shares traded) and then dividing by the total shares traded.

# %%
data['Date'].max()
# Out:
# Timestamp('2019-05-13 00:00:00')

# %%
data['Month'] = pd.DatetimeIndex(data['Date']).month
data['Year'] = pd.DatetimeIndex(data['Date']).year

# %%
data.head(10)
# Out:
#      Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0  MINDTREE     EQ 2017-05-15      510.60      507.35      515.00     505.90
# 1  MINDTREE     EQ 2017-05-16      509.45      507.00      515.85     506.00
# 2  MINDTREE     EQ 2017-05-17      511.30      507.05      519.70     502.75
# 3  MINDTREE     EQ 2017-05-18      506.35      502.00      516.75     486.00
# 4  MINDTREE     EQ 2017-05-19      492.90      491.95      502.95     489.50
# 5  MINDTREE     EQ 2017-05-22      497.50      499.95      511.85     497.10
# 6  MINDTREE     EQ 2017-05-23      502.35      504.00      507.45     491.00
# 7  MINDTREE     EQ 2017-05-24      501.15      502.00      515.00     494.05
# 8  MINDTREE     EQ 2017-05-25      509.95      513.70      549.50     508.45
# 9  MINDTREE     EQ 2017-05-26      543.90      540.00      544.00     532.00
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# ...

# %%
data.tail()
# Out:
#        Symbol Series       Date  Prev Close  Open Price  High Price  \
# 489  MINDTREE     EQ 2019-05-07      981.75       982.8      985.00
# 490  MINDTREE     EQ 2019-05-08      979.95       981.0      985.00
# 491  MINDTREE     EQ 2019-05-09      980.50       979.6      983.15
# 492  MINDTREE     EQ 2019-05-10      980.45       980.4      982.90
# 493  MINDTREE     EQ 2019-05-13      975.35       973.4      983.00
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 489     975.00       981.0       979.95         979.77                1242934
# 490     971.05       982.0       980.50         979.84                4301316
# 491     976.10       980.9       980.45         980.02                3787159
# 492     973.00       974.0       975.35         977.55                 215170
# 493     970.30       981.0       979.10         980.16                 485941
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# ...

# %% [markdown]
# #### Now we have separate columns for Year and Month

# %%
data['Month'].min()
# Out:
# 1

# %%
data['Month'].max()
# Out:
# 12

# %%
data['Year'].min()
# Out:
# 2017

# %%
data['Year'].max()
# Out:
# 2019

# %% [markdown]
# #### Therefore, the entire dataset is divided into 1st(January) to 12th(December) month and 2017 and 2019.

# %%
data_month = data.groupby(['Month'])
data_year = data.groupby(['Year'])

# %%
data_month.head(1)
# Out:
#        Symbol Series       Date  Prev Close  Open Price  High Price  \
# 0    MINDTREE     EQ 2017-05-15      510.60      507.35      515.00
# 13   MINDTREE     EQ 2017-06-01      543.95      545.05      549.00
# 34   MINDTREE     EQ 2017-07-03      529.00      530.90      534.00
# 55   MINDTREE     EQ 2017-08-01      477.45      477.35      479.20
# 76   MINDTREE     EQ 2017-09-01      461.00      463.30      466.60
# 97   MINDTREE     EQ 2017-10-03      464.85      465.00      482.05
# 117  MINDTREE     EQ 2017-11-01      479.65      483.30      484.00
# 139  MINDTREE     EQ 2017-12-01      539.20      539.45      547.60
# 159  MINDTREE     EQ 2018-01-01      612.40      610.80      618.35
# 181  MINDTREE     EQ 2018-02-01      770.00      765.55      769.00
# 200  MINDTREE     EQ 2018-03-01      815.10      820.00      824.35
# 219  MINDTREE     EQ 2018-04-02      771.95      782.00      812.80
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# ...

# %% [markdown]
# #### Therefore, the data starts from May 2017 and goes on to 2019
# #### Entries from 219 onto 494 are from May 2018 to 2019

# %%
data_year.head(1)
# Out:
#        Symbol Series       Date  Prev Close  Open Price  High Price  \
# 0    MINDTREE     EQ 2017-05-15       510.6      507.35      515.00
# 159  MINDTREE     EQ 2018-01-01       612.4      610.80      618.35
# 405  MINDTREE     EQ 2019-01-01       864.5      864.00      867.10
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0        505.9      510.50       509.45         510.39                 271952
# 159      605.3      606.05       606.90         610.63                 318744
# 405      853.4      863.15       863.40         861.25                 399996
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# 0    1.388005e+08           8261           100362                   36.90
# 159  1.946341e+08           6312           107284                   33.66
# 405  3.444982e+08           7996            27003                    6.75
#
#      Index  Month  Year
# 0        0      5  2017
# 159    159      1  2018
# ...

# %% [markdown]
# #### Entries from 0 - 158 : 2017
# #### Entries from 159 - 404 : 2018
# #### Entries rom 405 - 494 : 2019

# %%
data_month.mean()
# Out:
#        Prev Close  Open Price  High Price   Low Price  Last Price  \
# Month
# 1      764.577778  766.562222  782.050000  754.606667  768.474444
# 2      818.662821  818.225641  832.753846  805.462821  820.478205
# 3      869.611842  872.440789  884.298684  858.665789  869.925000
# 4      923.841250  927.175000  943.592500  917.987500  933.195000
# 5      860.183721  862.483721  873.510465  849.996512  859.406977
# 6      764.789286  767.298810  775.370238  751.958333  764.352381
# 7      762.861628  763.955814  773.380233  749.638372  760.424419
# 8      732.083333  732.697619  744.997619  724.188095  735.947619
# 9      764.624359  766.255128  776.639744  751.020513  764.087179
# 10     714.117073  711.752439  726.520732  695.232927  709.947561
# 11     663.884524  665.002381  676.779762  654.719048  666.007143
# 12     714.936250  715.086250  727.925000  704.168750  715.745000
#
#        Close Price  Average Price  Total Traded Quantity      Turnover  \
# Month
# ...

# %%
data_year.mean()
# Out:
#       Prev Close  Open Price  High Price   Low Price  Last Price  Close Price  \
# Year
# 2017  504.475157  504.951572  512.437421  497.979245  504.819182   505.115409
# 2018  905.140447  906.657927  922.840244  889.942073  906.680894   906.165244
# 2019  917.932584  919.739326  930.452247  908.499438  919.437079   919.220225
#
#       Average Price  Total Traded Quantity      Turnover  No. of Trades  \
# Year
# 2017     505.836415           5.808072e+05  3.001232e+08   13549.641509
# 2018     906.759797           1.804320e+06  1.643528e+09   43881.227642
# 2019     919.853371           1.682753e+06  1.535284e+09   37789.528090
#
#       Deliverable Qty  % Dly Qt to Traded Qty  Index     Month
# Year
# 2017    219460.974843               37.950629   79.0  8.660377
# 2018    384979.085366               23.272033  281.5  6.467480
# 2019    466332.516854               29.878090  449.0  2.651685

# %%
data_month['Close Price'].mean()
# Out:
# Month
# 1     768.736667
# 2     820.197436
# 3     869.415789
# 4     932.576250
# 5     859.126744
# 6     763.932143
# 7     760.393023
# 8     736.034524
# 9     762.634615
# 10    710.029268
# 11    665.916667
# 12    716.462500
# Name: Close Price, dtype: float64

# %%
data_year['Close Price'].mean()
# Out:
# Year
# 2017    505.115409
# 2018    906.165244
# 2019    919.220225
# Name: Close Price, dtype: float64

# %% [markdown]
# #### Create new column for product of Close Price and Total Traded Quantity (ie. Volume)

# %%
#data['VWAP'] = (data.groupby('Month')['Close Price'].mean() * data.groupby('Month')['Total Traded Quantity'].mean())

# %%
"""def vwap(df):
    q = df['Total Traded Quantity']
    p = df['Close Price']
    return data.assign(vwap =(p * q).cumsum() / q.cumsum())

data.groupby(data['Month'], group_keys = False).apply(vwap)"""
# Out:
# "def vwap(df):\n    q = df['Total Traded Quantity']\n    p = df['Close Price']\n    return data.assign(vwap =(p * q).cumsum() / q.cumsum())\n\ndata.groupby(data['Month'], group_keys = False).apply(vwap)"

# %%
#below wrong, use cumsum
#groupby_month['VWAP'] = (groupby_month['Close Price']*groupby_month['Total Traded Quantity'])/groupby_month['Total Traded Quantity']

# %%
#groupby_month.sort_values(['Month'], axis=0, ascending=True, inplace=True)

# %%
data_month

# %%
data_jan = data_month.get_group(1)

# %%
data_jan.tail()
# Out:
#        Symbol Series       Date  Prev Close  Open Price  High Price  \
# 423  MINDTREE     EQ 2019-01-25      910.40      916.05      925.00
# 424  MINDTREE     EQ 2019-01-28      886.10      872.00      884.25
# 425  MINDTREE     EQ 2019-01-29      868.60      870.00      911.00
# 426  MINDTREE     EQ 2019-01-30      903.60      909.20      919.00
# 427  MINDTREE     EQ 2019-01-31      890.45      900.00      902.00
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 423     880.80      887.95       886.10         903.83                2686280
# 424     856.05      868.15       868.60         870.47                2225129
# 425     866.00      907.35       903.60         890.49                1990949
# 426     885.10      890.00       890.45         902.76                1661063
# 427     880.00      893.90       894.05         892.33                1211981
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# ...

# %%
#data_jan['Price_Vol'] = data_jan.apply(lambda row: (row['Close Price']*row['Total Traded Quantity'], axis = 1))

# %%
data_jan.dtypes
# Out:
# Symbol                            object
# Series                            object
# Date                      datetime64[ns]
# Prev Close                       float64
# Open Price                       float64
# High Price                       float64
# Low Price                        float64
# Last Price                       float64
# Close Price                      float64
# Average Price                    float64
# Total Traded Quantity              int64
# Turnover                         float64
# No. of Trades                      int64
# Deliverable Qty                    int64
# % Dly Qt to Traded Qty           float64
# Index                              int64
# Month                              int64
# Year                               int64
# dtype: object

# %%
data_jan['Price_Vol'] = data_jan['Close Price'] * data_jan['Total Traded Quantity']

# %%
data_jan.head()
# Out:
#        Symbol Series       Date  Prev Close  Open Price  High Price  \
# 159  MINDTREE     EQ 2018-01-01      612.40      610.80      618.35
# 160  MINDTREE     EQ 2018-01-02      606.90      603.05      611.35
# 161  MINDTREE     EQ 2018-01-03      605.05      606.00      613.80
# 162  MINDTREE     EQ 2018-01-04      599.30      601.00      605.75
# 163  MINDTREE     EQ 2018-01-05      599.90      600.50      605.00
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 159     605.30      606.05       606.90         610.63                 318744
# 160     598.00      605.05       605.05         604.00                 528274
# 161     595.70      599.50       599.30         606.68                 853218
# 162     593.05      599.45       599.90         599.41                1122243
# 163     597.00      602.00       602.30         600.57                 908732
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# ...

# %%
# Using cumulative sum to calculate VWAP for each day in January
data_jan['VWAP'] = data_jan['Price_Vol'].sum()/data_jan['Total Traded Quantity'].sum()

# %%
data_jan.head()
# Out:
#        Symbol Series       Date  Prev Close  Open Price  High Price  \
# 159  MINDTREE     EQ 2018-01-01      612.40      610.80      618.35
# 160  MINDTREE     EQ 2018-01-02      606.90      603.05      611.35
# 161  MINDTREE     EQ 2018-01-03      605.05      606.00      613.80
# 162  MINDTREE     EQ 2018-01-04      599.30      601.00      605.75
# 163  MINDTREE     EQ 2018-01-05      599.90      600.50      605.00
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 159     605.30      606.05       606.90         610.63                 318744
# 160     598.00      605.05       605.05         604.00                 528274
# 161     595.70      599.50       599.30         606.68                 853218
# 162     593.05      599.45       599.90         599.41                1122243
# 163     597.00      602.00       602.30         600.57                 908732
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# ...

# %% [markdown]
# #### Approach used in 1.4 : Groupby month in main dataframe and then create new data frame for each month and calculate VWAP for each month individually. January is done in said method. Similar approach can be followed fro the other months.

# %% [markdown]
# # Problem Statement 1.5
# Write a function to calculate the average price over the last N days of the stock price data where N is a user defined parameter. Write a second function to calculate the profit/loss percentage over the last N days.
# Calculate the average price AND the profit/loss percentages over the course of last -
# 1 week, 2 weeks, 1 month, 3 months, 6 months and 1 year.
# {Note : Profit/Loss percentage between N days is the percentage change between the closing prices of the 2 days }

# %%
data.tail()
# Out:
#        Symbol Series       Date  Prev Close  Open Price  High Price  \
# 489  MINDTREE     EQ 2019-05-07      981.75       982.8      985.00
# 490  MINDTREE     EQ 2019-05-08      979.95       981.0      985.00
# 491  MINDTREE     EQ 2019-05-09      980.50       979.6      983.15
# 492  MINDTREE     EQ 2019-05-10      980.45       980.4      982.90
# 493  MINDTREE     EQ 2019-05-13      975.35       973.4      983.00
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 489     975.00       981.0       979.95         979.77                1242934
# 490     971.05       982.0       980.50         979.84                4301316
# 491     976.10       980.9       980.45         980.02                3787159
# 492     973.00       974.0       975.35         977.55                 215170
# 493     970.30       981.0       979.10         980.16                 485941
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# ...

# %%
n = input('Period of time to perform calculation(in days): ')
n = int(n)
# extracting the data for the user given number of days
data_n = data.loc[(data['Index'] >= 493 - n) & (data['Index'] <= 493)]

def avg_price(n):   
    ap = data_n['Close Price'].sum()/n
    print("Average price for the given time period: ", ap)

    
def pl_percentage(n):
    pl_df = data_n.iloc[[0, -1]]
    pl_df.head()
    a = pl_df['Close Price']
    a =a.pct_change()
    a = a.iloc[-1] * 100
    print("PL Percentage change for the given time period: ", a, "%")
    
avg_price(n)
pl_percentage(n)
# Out:
# Period of time to perform calculation(in days): 7
# Average price for the given time period:  1118.3857142857144
# PL Percentage change for the given time period:  -0.2343590788669192 %

# %% [markdown]
# Period of time to perform calculation(in days): 7
# Average price for the given time period:  1118.3857142857144
# PL Percentage change for the given time period:  -0.2343590788669192 %
#
#
# Period of time to perform calculation(in days): 14
# Average price for the given time period:  1048.1928571428573
# PL Percentage change for the given time period:  1.0944759938048554 %
#
#
# Period of time to perform calculation(in days): 30
# Average price for the given time period:  999.3366666666665
# PL Percentage change for the given time period:  3.008942661756975 %
#
#
# Period of time to perform calculation(in days): 90
# Average price for the given time period:  928.2133333333335
# PL Percentage change for the given time period:  13.308644832773986 %
#
#
# Period of time to perform calculation(in days): 180
# Average price for the given time period:  937.8138888888889
# PL Percentage change for the given time period:  -0.38661104893681353 %
#
#
# Period of time to perform calculation(in days): 365
# Average price for the given time period:  881.9361643835617
# PL Percentage change for the given time period:  91.67971808927173 %

# %% [markdown]
# # Problem Statement 1.6
#  Add a column 'Day_Perc_Change' where the values are the daily change in percentages i.e. the percentage change between 2 consecutive day's closing prices. Instead of using the basic mathematical formula for computing the same, use 'pct_change()' function provided by Pandas for dataframes. You will note that the first entry of the column will have a ‘Nan’ value. Why does this happen? Either remove the first row, or set the entry to 0 before proceeding.

# %%
data.head()
# Out:
#      Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0  MINDTREE     EQ 2017-05-15      510.60      507.35      515.00     505.90
# 1  MINDTREE     EQ 2017-05-16      509.45      507.00      515.85     506.00
# 2  MINDTREE     EQ 2017-05-17      511.30      507.05      519.70     502.75
# 3  MINDTREE     EQ 2017-05-18      506.35      502.00      516.75     486.00
# 4  MINDTREE     EQ 2017-05-19      492.90      491.95      502.95     489.50
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      510.50       509.45         510.39                 271952
# 1      511.00       511.30         512.69                 207011
# 2      504.00       506.35         512.10                 391401
# 3      487.50       492.90         505.60                 852336
# 4      495.15       497.50         496.43                 352273
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# ...

# %% [markdown]
# #### Calculating % Change using pct_change() function

# %%
data['Day_Perc_Change'] = data[['Close Price']].pct_change()*100
data.head()
# Out:
#      Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0  MINDTREE     EQ 2017-05-15      510.60      507.35      515.00     505.90
# 1  MINDTREE     EQ 2017-05-16      509.45      507.00      515.85     506.00
# 2  MINDTREE     EQ 2017-05-17      511.30      507.05      519.70     502.75
# 3  MINDTREE     EQ 2017-05-18      506.35      502.00      516.75     486.00
# 4  MINDTREE     EQ 2017-05-19      492.90      491.95      502.95     489.50
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      510.50       509.45         510.39                 271952
# 1      511.00       511.30         512.69                 207011
# 2      504.00       506.35         512.10                 391401
# 3      487.50       492.90         505.60                 852336
# 4      495.15       497.50         496.43                 352273
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# ...

# %% [markdown]
# #### Removing first row to avoid NaN Value

# %%
data = data.iloc[1:]
data.head()
# Out:
#      Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 1  MINDTREE     EQ 2017-05-16      509.45      507.00      515.85     506.00
# 2  MINDTREE     EQ 2017-05-17      511.30      507.05      519.70     502.75
# 3  MINDTREE     EQ 2017-05-18      506.35      502.00      516.75     486.00
# 4  MINDTREE     EQ 2017-05-19      492.90      491.95      502.95     489.50
# 5  MINDTREE     EQ 2017-05-22      497.50      499.95      511.85     497.10
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 1      511.00       511.30         512.69                 207011
# 2      504.00       506.35         512.10                 391401
# 3      487.50       492.90         505.60                 852336
# 4      495.15       497.50         496.43                 352273
# 5      501.55       502.35         504.78                 399974
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# ...

# %% [markdown]
# # Problem Statement 1.7
#
# Add another column 'Trend' whose values are:
#
#     'Slight or No change' for 'Day_Perc_Change' in between -0.5 and 0.5
#     'Slight positive' for 'Day_Perc_Change' in between 0.5 and 1
#     'Slight negative' for 'Day_Perc_Change' in between -0.5 and -1
#     'Positive' for 'Day_Perc_Change' in between 1 and 3
#     'Negative' for 'Day_Perc_Change' in between -1 and -3
#     'Among top gainers' for 'Day_Perc_Change' in between 3 and 7
#     'Among top losers' for 'Day_Perc_Change' in between -3 and -7
#     'Bull run' for 'Day_Perc_Change' >7
#     'Bear drop' for 'Day_Perc_Change' <-7

# %%
data['Trend'] = np.where(data['Day_Perc_Change']>= -0.5, 'Slight or No change', 'NA')
data['Trend'] = np.where(data['Day_Perc_Change']<= 0.5, 'Slight or No change', 'NA')
data['Trend'] = np.where(data['Day_Perc_Change']>= 0.5, 'Slight Positive', 'NA')
data['Trend'] = np.where(data['Day_Perc_Change']<= 1, 'Slight Positive', 'NA')
data['Trend'] = np.where(data['Day_Perc_Change']<= -0.5, 'Slight Negative', 'NA')
data['Trend'] = np.where(data['Day_Perc_Change']>= -1, 'Slight Negative', 'NA')
data['Trend'] = np.where(data['Day_Perc_Change']>= 1, 'Positive', 'NA')
data['Trend'] = np.where(data['Day_Perc_Change']<= 3, 'Positive', 'NA')
data['Trend'] = np.where(data['Day_Perc_Change']<= -1, 'Negative', 'NA')
data['Trend'] = np.where(data['Day_Perc_Change']>= -3, 'Negative', 'NA')
data['Trend'] = np.where(data['Day_Perc_Change']>= 3, 'Among top gainers', 'NA')
data['Trend'] = np.where(data['Day_Perc_Change']<= 7, 'Among top gainers', 'NA')
data['Trend'] = np.where(data['Day_Perc_Change']<= -3, 'Among top losers', 'NA')
data['Trend'] = np.where(data['Day_Perc_Change']>= -7, 'Among top losers', 'NA')
data['Trend'] = np.where(data['Day_Perc_Change']> 7, 'Bull run', 'NA')
data['Trend'] = np.where(data['Day_Perc_Change']< -7, 'Bear Drop', 'NA')

# %%
data.head()
# Out:
#      Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 1  MINDTREE     EQ 2017-05-16      509.45      507.00      515.85     506.00
# 2  MINDTREE     EQ 2017-05-17      511.30      507.05      519.70     502.75
# 3  MINDTREE     EQ 2017-05-18      506.35      502.00      516.75     486.00
# 4  MINDTREE     EQ 2017-05-19      492.90      491.95      502.95     489.50
# 5  MINDTREE     EQ 2017-05-22      497.50      499.95      511.85     497.10
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 1      511.00       511.30         512.69                 207011
# 2      504.00       506.35         512.10                 391401
# 3      487.50       492.90         505.60                 852336
# 4      495.15       497.50         496.43                 352273
# 5      501.55       502.35         504.78                 399974
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# ...

# %%
data.tail()
# Out:
#        Symbol Series       Date  Prev Close  Open Price  High Price  \
# 489  MINDTREE     EQ 2019-05-07      981.75       982.8      985.00
# 490  MINDTREE     EQ 2019-05-08      979.95       981.0      985.00
# 491  MINDTREE     EQ 2019-05-09      980.50       979.6      983.15
# 492  MINDTREE     EQ 2019-05-10      980.45       980.4      982.90
# 493  MINDTREE     EQ 2019-05-13      975.35       973.4      983.00
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 489     975.00       981.0       979.95         979.77                1242934
# 490     971.05       982.0       980.50         979.84                4301316
# 491     976.10       980.9       980.45         980.02                3787159
# 492     973.00       974.0       975.35         977.55                 215170
# 493     970.30       981.0       979.10         980.16                 485941
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# ...
